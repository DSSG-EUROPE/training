# %% [markdown]
# We learn how to process csv files using command lines, import to the database, now we willlearn how to manipulate the data in Python

# %%
import numpy as np
import pandas as pd
import psycopg2 as pg
# %matplotlib inline

# %%
# Connect to an existing database
conn = pg.connect(dbname="postgres", host="db.dssg.io", user="qhan", password="dssg-2017")

# %% [markdown]
# conn.cursor will return a cursor object, you can use this cursor to perform queries

# %%
cur = conn.cursor()
print "Connection success!"
# Out:
# Connection success!

# %% [markdown]
# Then we can execute the SQL queries and fetch the results

# %%
script = "select * from qhan.weather limit 1000;"
cur.execute(script)
results = cur.fetchall()

# %%
print results
# Out:
# [('US1TXCML112', datetime.date(2016, 4, 16), 'RAIN', 5, None, None, 'N', None), ('US1TXBEL028', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'N', None), ('US1TXBEL028', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, 'N', None), ('US1TXAG0003', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'N', None), ('US1TXAG0003', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, 'N', None), ('US1TNGN0008', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'N', None), ('US1TNCF0027', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'N', None), ('US1TNCF0027', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, 'N', None), ('ASN00109512', datetime.date(2016, 4, 16), 'RAIN', 10, None, None, 'a', None), ('US1SDKY0009', datetime.date(2016, 4, 16), 'RAIN', 5, None, None, 'N', None), ('BL000085365', datetime.date(2016, 4, 16), 'TMAX', 305, None, None, 'S', None), ('BL000085365', datetime.date(2016, 4, 16), 'TAVG', 275, 'H', None, 'S', None), ('US1TXBEE018', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'N', None), ('US1TXBEE018', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, 'N', None), ('ASN00096003', datetime.date(2016, 4, 16), 'TMAX', 95, None, None, 'a', None), ('ASN00096003', datetime.date(2016, 4, 16), 'TMIN', 63, None, None, 'a', None), ('ASN00096003', datetime.date(2016, 4, 16), 'RAIN', 10, None, None, 'a', None), ('CI000085469', datetime.date(2016, 4, 16), 'TAVG', 225, 'H', None, 'S', None), ('US1SCOC0060', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'N', None), ('US1SCOC0060', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, 'N', None), ('CHM00056768', datetime.date(2016, 4, 16), 'TMAX', 262, None, None, 'S', None), ('CHM00056768', datetime.date(2016, 4, 16), 'TMIN', 129, None, None, 'S', None), ('CHM00056768', datetime.date(2016, 4, 16), 'RAIN', 18, None, None, 'S', None), ('CHM00056768', datetime.date(2016, 4, 16), 'TAVG', 196, 'H', None, 'S', None), ('CHM00053646', datetime.date(2016, 4, 16), 'TMIN', 26, None, None, 'S', None), ('CHM00053646', datetime.date(2016, 4, 16), 'TAVG', 100, 'H', None, 'S', None), ('CD000064754', datetime.date(2016, 4, 16), 'TMIN', 230, None, None, 'S', None), ('CD000064754', datetime.date(2016, 4, 16), 'TAVG', 354, 'H', None, 'S', None), ('ASN00092040', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'a', None), ('USC00251575', datetime.date(2016, 4, 16), 'TMAX', 133, None, None, '7', '0700'), ('USC00251575', datetime.date(2016, 4, 16), 'TMIN', 33, None, None, '7', '0700'), ('USC00251575', datetime.date(2016, 4, 16), 'TOBS', 33, None, None, '7', '0700'), ('USC00251575', datetime.date(2016, 4, 16), 'RAIN', 0, 'T', None, '7', '0700'), ('USC00251575', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, '7', None), ('USC00251575', datetime.date(2016, 4, 16), 'SNWD', 0, None, None, '7', '0700'), ('USC00257545', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, '7', '0700'), ('USC00257545', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, '7', None), ('USC00257545', datetime.date(2016, 4, 16), 'SNWD', 0, None, None, '7', '0700'), ('USC00251200', datetime.date(2016, 4, 16), 'TMAX', 194, None, None, '7', '0700'), ('USC00251200', datetime.date(2016, 4, 16), 'TMIN', 122, None, None, '7', '0700'), ('USC00251200', datetime.date(2016, 4, 16), 'TOBS', 122, None, None, '7', '0700'), ('USC00251200', datetime.date(2016, 4, 16), 'RAIN', 0, 'T', None, '7', '0700'), ('USC00251200', datetime.date(2016, 4, 16), 'SNOW', 0, None, None, '7', None), ('USC00251200', datetime.date(2016, 4, 16), 'SNWD', 0, None, None, '7', '0700'), ('ASN00054023', datetime.date(2016, 4, 16), 'RAIN', 0, None, None, 'a', None), ('USC00250050', datetime.date(2016, 4, 16), 'TMAX', 178, None, None, '7', '1800'), ('USC00250050', datetime.date(2016, 4, 16), 'TMIN', 33, None, None, '7', '1800'), ('USC00250050', datetime.date(2016, 4, 16), 'TOBS', 33, None, None, '7', '1800'), ('USC00250050', datetime.date(2016, 4, 16), 'RAIN', 43, None, None, '7', '1800'), ('USC00250050', datetime.date(2016, 4, 16), 'SNOW', 0, None, Non ...

# %%
type(results)
# Out:
# list

# %% [markdown]
# The pandas DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes. It's basically a spreadsheet you can program and it's an incredibly useful Python object for data analysis.

# %%
results_df = pd.read_sql(script, con=conn)
type(results_df)
# Out:
# pandas.core.frame.DataFrame

# %%
results_df
# Out:
#          station        date value_type  value measurement_flag quality_flag  \
# 0    US1TXCML112  2016-04-16       RAIN      5             None         None
# 1    US1TXBEL028  2016-04-16       RAIN      0             None         None
# 2    US1TXBEL028  2016-04-16       SNOW      0             None         None
# 3    US1TXAG0003  2016-04-16       RAIN      0             None         None
# 4    US1TXAG0003  2016-04-16       SNOW      0             None         None
# 5    US1TNGN0008  2016-04-16       RAIN      0             None         None
# 6    US1TNCF0027  2016-04-16       RAIN      0             None         None
# 7    US1TNCF0027  2016-04-16       SNOW      0             None         None
# 8    ASN00109512  2016-04-16       RAIN     10             None         None
# 9    US1SDKY0009  2016-04-16       RAIN      5             None         None
# 10   BL000085365  2016-04-16       TMAX    305             None         None
# 11   BL000085365  2016-04-16       TAVG    275                H         None
# 12   US1TXBEE018  2016-04-16       RAIN      0             None         None
# 13   US1TXBEE018  2016-04-16       SNOW      0             None         None
# 14   ASN00096003  2016-04-16       TMAX     95             None         None
# 15   ASN00096003  2016-04-16       TMIN     63             None         None
# 16   ASN00096003  2016-04-16       RAIN     10             None         None
# 17   CI000085469  2016-04-16       TAVG    225                H         None
# 18   US1SCOC0060  2016-04-16       RAIN      0             None         None
# 19   US1SCOC0060  2016-04-16       SNOW      0             None         None
# 20   CHM00056768  2016-04-16       TMAX    262             None         None
# 21   CHM00056768  2016-04-16       TMIN    129             None         None
# 22   CHM00056768  2016-04-16       RAIN     18             None         None
# 23   CHM00056768  2016-04-16       TAVG    196                H         None
# 24   CHM00053646  2016-04-16       TMIN     26             None         None
# 25   CHM00053646  2016-04-16       TAVG    100                H         None
# 26   CD000064754  2016-04-16       TMIN    230             None         None
# 27   CD000064754  2016-04-16       TAVG    354                H         None
# 28   ASN00092040  2016-04-16       RAIN      0             None         None
# 29   USC00251575  2016-04-16       TMAX    133             None         None
# ..           ...         ...        ...    ...              ...          ...
# 970  USW00013968  2016-04-16       WSF2    103             None         None
# 971  USW00013968  2016-04-16       WSF5    139             None         None
# 972  USW00003728  2016-04-16       TMAX    201             None         None
# 973  USW00003728  2016-04-16       TMIN     94             None         None
# 974  USW00003728  2016-04-16       RAIN      0             None         None
# 975  ASN00032031  2016-04-16       RAIN    354             None         None
# 976  USW00012975  2016-04-16       TMAX    261             None         None
# 977  USW00012975  2016-04-16       TMIN    189             None         None
# 978  USW00012975  2016-04-16       RAIN      8             None         None
# 979  USW00012975  2016-04-16       SNOW      0             None         None
# 980  USW00012975  2016-04-16       SNWD      0             None         None
# 981  USW00012975  2016-04-16       AWND     68             None         None
# 982  USW00012975  2016-04-16       WDF2    110             None         None
# 983  USW00012975  2016-04-16       WDF5    120             None         None
# 984  USW00012975  2016-04-16       WSF2    125             None         None
# 985  USW00012975  2016-04-16       WSF5    179             None         None
# 986  USW00012975  2016-04-16       WT01      1             None         None
# 987  USW00003179  2016-04-16       TMAX    306             None         None
# 988  USW00003179  2016-04-16       TMIN    128             None         None
# 989  USW00003179  2016-04-16       RAIN      0             None         None
# 990  USW00003179  2016-04-16       SNOW      0             None         None
# 991  USW00003179  2016-04-16       SNWD      0             None         None
# 992  USW00003179  2016-04-16       AWND     46             None         None
# 993  USW00003179  2016-04-16       WDF2     90             None         None
# 994  USW00003179  2016-04-16       WDF5     80             None         None
# 995  USW00003179  2016-04-16       WSF2    107             None         None
# 996  USW00003179  2016-04-16       WSF5    152             None         None
# 997  USW00003179  2016-04-16       WT08      1             None         None
# 998  USS0021B60S  2016-04-16       TMAX    140             None         None
# 999  USS0021B60S  2016-04-16       TMIN     30             None         None
#
#     source_flag  time
# 0             N  None
# 1             N  None
# 2             N  None
# 3             N  None
# 4             N  None
# 5             N  None
# 6             N  None
# 7             N  None
# 8             a  None
# 9             N  None
# 10            S  None
# 11            S  None
# 12            N  None
# 13            N  None
# 14            a  None
# 15            a  None
# 16            a  None
# 17            S  None
# 18            N  None
# 19            N  None
# 20            S  None
# 21            S  None
# 22            S  None
# 23            S  None
# 24            S  None
# 25            S  None
# 26            S  None
# 27            S  None
# 28            a  None
# 29            7  0700
# ..          ...   ...
# 970           W  None
# 971           W  None
# 972           R  None
# 973           R  None
# 974           R  None
# 975           a  None
# 976           W  None
# 977           W  None
# 978           W  None
# 979           W  None
# 980           W  None
# 981           W  None
# 982           W  None
# 983           W  None
# 984           W  None
# 985           W  None
# 986           W  None
# 987           W  None
# 988           W  None
# 989           W  None
# 990           W  None
# 991           W  None
# 992           W  None
# 993           W  None
# 994           W  None
# 995           W  None
# 996           W  None
# 997           W  None
# 998           T  None
# 999           T  None
#
# [1000 rows x 8 columns]

# %% [markdown]
# Viewing data in pandas
#
# There are lots of options for viewing data in pandas. Just like we did in the command line, you can use head and tail to get a quick view of our data

# %%
results_df.head()
# Out:
#        station        date value_type  value measurement_flag quality_flag  \
# 0  US1TXCML112  2016-04-16       RAIN      5             None         None
# 1  US1TXBEL028  2016-04-16       RAIN      0             None         None
# 2  US1TXBEL028  2016-04-16       SNOW      0             None         None
# 3  US1TXAG0003  2016-04-16       RAIN      0             None         None
# 4  US1TXAG0003  2016-04-16       SNOW      0             None         None
#
#   source_flag  time
# 0           N  None
# 1           N  None
# 2           N  None
# 3           N  None
# 4           N  None

# %%
results_df.tail()
# Out:
#          station        date value_type  value measurement_flag quality_flag  \
# 995  USW00003179  2016-04-16       WSF2    107             None         None
# 996  USW00003179  2016-04-16       WSF5    152             None         None
# 997  USW00003179  2016-04-16       WT08      1             None         None
# 998  USS0021B60S  2016-04-16       TMAX    140             None         None
# 999  USS0021B60S  2016-04-16       TMIN     30             None         None
#
#     source_flag  time
# 995           W  None
# 996           W  None
# 997           W  None
# 998           T  None
# 999           T  None

# %%
results_df.shape
# Out:
# (1000, 8)

# %% [markdown]
# We can choose the subset of data by selecting both rows and columns

# %%
# Look at the first 3 rows
results_df[:3]
# Out:
#        station        date value_type  value measurement_flag quality_flag  \
# 0  US1TXCML112  2016-04-16       RAIN      5             None         None
# 1  US1TXBEL028  2016-04-16       RAIN      0             None         None
# 2  US1TXBEL028  2016-04-16       SNOW      0             None         None
#
#   source_flag  time
# 0           N  None
# 1           N  None
# 2           N  None

# %% [markdown]
# Modifying your dataframe
#
# Notice that some columns are completely useless. Let's fix that by learning how to delete columns.
#
# This is similar as writing SQL script: select station, date as record_date, value_type, value
# from qhan.weather

# %%
results_df[['station', 'date', 'value_type', 'value']][:10]
# Out:
#        station        date value_type  value
# 0  US1TXCML112  2016-04-16       RAIN      5
# 1  US1TXBEL028  2016-04-16       RAIN      0
# 2  US1TXBEL028  2016-04-16       SNOW      0
# 3  US1TXAG0003  2016-04-16       RAIN      0
# 4  US1TXAG0003  2016-04-16       SNOW      0
# 5  US1TNGN0008  2016-04-16       RAIN      0
# 6  US1TNCF0027  2016-04-16       RAIN      0
# 7  US1TNCF0027  2016-04-16       SNOW      0
# 8  ASN00109512  2016-04-16       RAIN     10
# 9  US1SDKY0009  2016-04-16       RAIN      5

# %%
# Delete these rows 
weather = results_df.drop(['measurement_flag', 'quality_flag', 'source_flag', 'time'], axis=1)

# %% [markdown]
# Describing the entire dataframe
#
# Now that we have columns, we want to get a better global view of our data. There are several ways

# %%
weather.describe(include=['O'])
# Out:
#             station        date value_type
# count          1000        1000       1000
# unique          351           1         26
# top     USW00013968  2016-04-16       RAIN
# freq             11        1000        309

# %%
weather['value_type'].value_counts()
# Out:
# RAIN    309
# SNOW    146
# TMAX    125
# TMIN    121
# SNWD     83
# TAVG     60
# TOBS     47
# AWND     14
# WSF2     13
# WSF5     13
# WDF5     13
# WDF2     13
# WESD     11
# WESF     10
# WSFG      5
# PGTM      4
# WDFG      4
# EVAP      1
# MDPR      1
# WT03      1
# SN32      1
# WT01      1
# WDMV      1
# WT08      1
# DAPR      1
# SX32      1
# Name: value_type, dtype: int64

# %%
weather['value_type'].value_counts().plot(kind='bar')

# %% [markdown]
# Subset of dataset similar as select * from weather where value_type == 'RAIN'

# %%
weather[weather['value_type'] == "RAIN"]
# Out:
#          station        date value_type  value
# 0    US1TXCML112  2016-04-16       RAIN      5
# 1    US1TXBEL028  2016-04-16       RAIN      0
# 3    US1TXAG0003  2016-04-16       RAIN      0
# 5    US1TNGN0008  2016-04-16       RAIN      0
# 6    US1TNCF0027  2016-04-16       RAIN      0
# 8    ASN00109512  2016-04-16       RAIN     10
# 9    US1SDKY0009  2016-04-16       RAIN      5
# 12   US1TXBEE018  2016-04-16       RAIN      0
# 16   ASN00096003  2016-04-16       RAIN     10
# 18   US1SCOC0060  2016-04-16       RAIN      0
# 22   CHM00056768  2016-04-16       RAIN     18
# 28   ASN00092040  2016-04-16       RAIN      0
# 32   USC00251575  2016-04-16       RAIN      0
# 35   USC00257545  2016-04-16       RAIN      0
# 41   USC00251200  2016-04-16       RAIN      0
# 44   ASN00054023  2016-04-16       RAIN      0
# 48   USC00250050  2016-04-16       RAIN     43
# 54   USC00247620  2016-04-16       RAIN      0
# 59   NLE00108966  2016-04-16       RAIN     12
# 61   NLE00108960  2016-04-16       RAIN     34
# 65   NLE00100496  2016-04-16       RAIN      4
# 70   USC00238740  2016-04-16       RAIN      0
# 75   MXM00076593  2016-04-16       RAIN      0
# 80   USC00229400  2016-04-16       RAIN    381
# 88   MXM00076040  2016-04-16       RAIN      0
# 93   CA1SK000069  2016-04-16       RAIN      0
# 94   US1ORLN0045  2016-04-16       RAIN      0
# 96   CA1PE000023  2016-04-16       RAIN      0
# 98   CA1NS000015  2016-04-16       RAIN    168
# 99   CA1NS000068  2016-04-16       RAIN      0
# ..           ...         ...        ...    ...
# 877  ASN00074148  2016-04-16       RAIN      0
# 879  ASN00074106  2016-04-16       RAIN      0
# 880  US1IAUN0001  2016-04-16       RAIN      0
# 884  ASN00073151  2016-04-16       RAIN      0
# 885  US1GALW0015  2016-04-16       RAIN     71
# 886  US1GAMA0022  2016-04-16       RAIN      0
# 888  US1IATY0002  2016-04-16       RAIN      0
# 890  US1GAHL0001  2016-04-16       RAIN      0
# 891  ASN00072012  2016-04-16       RAIN      2
# 892  US1GACT0059  2016-04-16       RAIN      3
# 893  US1DESS0016  2016-04-16       RAIN      0
# 895  US1FLHN0011  2016-04-16       RAIN    142
# 896  ASN00033268  2016-04-16       RAIN      0
# 897  US1FLMT0019  2016-04-16       RAIN     99
# 901  US1COLR0495  2016-04-16       RAIN     48
# 906  US1COGL0015  2016-04-16       RAIN    198
# 908  US1COGR0052  2016-04-16       RAIN    201
# 914  USW00053120  2016-04-16       RAIN      0
# 923  UY000086565  2016-04-16       RAIN   1905
# 928  US1COEP0180  2016-04-16       RAIN     46
# 934  USW00014828  2016-04-16       RAIN      0
# 939  USW00014829  2016-04-16       RAIN      0
# 949  USW00025506  2016-04-16       RAIN      0
# 956  US1COEP0037  2016-04-16       RAIN     41
# 960  ASN00066158  2016-04-16       RAIN      0
# 963  USW00013968  2016-04-16       RAIN      0
# 974  USW00003728  2016-04-16       RAIN      0
# 975  ASN00032031  2016-04-16       RAIN    354
# 978  USW00012975  2016-04-16       RAIN      8
# 989  USW00003179  2016-04-16       RAIN      0
#
# [309 rows x 4 columns]

# %% [markdown]
# select station, date, value_type,
# value from qhan.weather
# where value_type = 'RAIN' and value > 300;

# %%
weather[(weather['value_type'] == "RAIN") & (weather['value'] > 300)]
# Out:
#          station        date value_type  value
# 80   USC00229400  2016-04-16       RAIN    381
# 215  US1KSSV0018  2016-04-16       RAIN    678
# 216  US1KSLG0005  2016-04-16       RAIN    320
# 652  US1OKCM0007  2016-04-16       RAIN   1270
# 676  CA1ON000218  2016-04-16       RAIN    320
# 840  US1KSST0001  2016-04-16       RAIN    305
# 841  US1KSSV0019  2016-04-16       RAIN    815
# 923  UY000086565  2016-04-16       RAIN   1905
# 975  ASN00032031  2016-04-16       RAIN    354

# %%
weather['datetime'] = pd.to_datetime(weather.date, format='%Y-%m-%d')

# %%
weather.dtypes
# Out:
# station               object
# date                  object
# value_type            object
# value                  int64
# datetime      datetime64[ns]
# dtype: object

# %% [markdown]
# select count(distinct station) as number_stations
# from weather
# where date between '2016-01-01' and '2016-02-01'
# and value_type = 'SNOW'
# and value > 100;

# %%
weather[(weather['value_type'] == "SNOW") & (weather['value'] > 300) 
        & (weather['datetime'] > "2016-01-01") & (weather['datetime'] < "2016-02-01")]
# Out:
# Empty DataFrame
# Columns: [station, date, value_type, value, datetime]
# Index: []

# %% [markdown]
# Groupby is a powerful method that makes it easy to peform operations on the dataframe by categorial values. Let's try generating a plot of min, max, and average temp over time.

# %%
weather.groupby('value_type').value.mean()
# Out:
# value_type
# AWND      37.000000
# DAPR       5.000000
# EVAP      51.000000
# MDPR     249.000000
# PGTM    1677.250000
# RAIN      34.974110
# SN32      56.000000
# SNOW       4.849315
# SNWD     101.481928
# SX32     117.000000
# TAVG     134.100000
# TMAX     188.760000
# TMIN      68.661157
# TOBS      89.425532
# WDF2     118.461538
# WDF5     120.000000
# WDFG      67.500000
# WDMV      51.000000
# WESD    2126.727273
# WESF      31.100000
# WSF2      88.384615
# WSF5     118.769231
# WSFG      30.400000
# WT01       1.000000
# WT03       1.000000
# WT08       1.000000
# Name: value, dtype: float64

# %%
prip = weather[weather['value_type'].isin(["RAIN", "SNOW"])]

# %%
prip.value_type.value_counts()
# Out:
# RAIN    309
# SNOW    146
# Name: value_type, dtype: int64

# %%
prip.value.plot()

# %% [markdown]
# agg(regation) method allows you to run summary statistics after you groupby the records

# %%
prip.groupby('value_type').value.agg(['count','min','max','mean'])
# Out:
#             count  min   max       mean
# value_type
# RAIN          309    0  1905  34.974110
# SNOW          146    0   318   4.849315

# %%
weather.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)
